# %%
# !gdown --id '19CzXudqN58R3D-1G8KeFWk8UDQwlb8is' --output food-11.zip # 下載資料集
# !unzip food-11.zip # 解壓縮
# Out:
# 'gdown' 不是内部或外部命令，也不是可运行的程序
# 或批处理文件。
# 'unzip' 不是内部或外部命令，也不是可运行的程序
# 或批处理文件。

# %%
# !mkdir little_ds
# !ls
# Out:
# food-11  food-11.zip  little_ds  sample_data

# %%
# !cp food-11/validation/*_1.jpg little_ds/.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, Dataset
import torch.optim as optim

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import cv2
import torchvision.transforms as transforms
from PIL import Image

import os
import time

# %% [markdown]
# # 新段落

# %%
class MyDataset(Dataset):
    def __init__(self, file_path, transform, with_label):
        self.transform = transform
        data_list = os.listdir(file_path)
        self.label_container = []
        self.data_container = []
        self.with_label = with_label
        self.data_len = len(data_list)
        for i, data in enumerate(data_list):
            img_dir = file_path + data
            self.data_container.append(img_dir)
            self.label_container.append(int(data.split("_")[0]))
        if self.with_label:
          print("class number: {}".format(len(set(self.label_container))))

    def __getitem__(self, index):
        img = Image.open(self.data_container[index]).convert('RGB')
        if self.transform:
            img = self.transform(img)
        if self.with_label:
            label = self.label_container[index]
        if self.with_label:
            return img, label
        else:
            return img

    def __len__(self):
        return self.data_len

# %%
train_path = './food-11/training/'
test_path = './food-11/testing/'
valid_path = './food-11/validation/'
little_path = './little_ds/'
train_transform = transforms.Compose([transforms.Resize((128, 128)), transforms.ToTensor()])

train_ds = MyDataset(train_path, transform=train_transform , with_label=True)
# Out:
# class number: 11

# %%
for i in range(5):
  img, label = train_ds[i]
  plt.figure(i)
  fig, ax = plt.subplots()
  ax.imshow(img.permute(1, 2, 0).numpy())
  ax.set_title("class {}".format(label))
  ax.set_xticks([])
  ax.set_yticks([])
plt.show()

# %%
class ResBlk(nn.Module):
    """resnet block"""
    def __init__(self, ch_in, ch_out, stride=1):
        """
        :param ch_in:
        :param ch_out:
        """
        super(ResBlk, self).__init__()

        # we add stride support for resbok, which is distinct from tutorials.
        self.conv1 = nn.Conv2d(ch_in, ch_out, kernel_size=3, stride=stride, padding=1)
        self.bn1 = nn.BatchNorm2d(ch_out)
        self.conv2 = nn.Conv2d(ch_out, ch_out, kernel_size=3, stride=1, padding=1)
        self.bn2 = nn.BatchNorm2d(ch_out)

        self.extra = nn.Sequential()
        if ch_out != ch_in:
            # [b, ch_in, h, w] => [b, ch_out, h, w]
            self.extra = nn.Sequential(
                nn.Conv2d(ch_in, ch_out, kernel_size=1, stride=stride),
                nn.BatchNorm2d(ch_out)
            )


    def forward(self, x):
        """
        :param x: [b, ch, h, w]
        :return:
        """
        # print("==")
        out = F.relu(self.bn1(self.conv1(x)))
        # print(out.shape)
        out = self.bn2(self.conv2(out))
        # print(out.shape)
        # short cut.
        # extra module: [b, ch_in, h, w] => [b, ch_out, h, w]
        # element-wise add:
        out = self.extra(x) + out
        out = F.relu(out)
        
        return out

# %%
class ResNet18(nn.Module):

    def __init__(self):
        super(ResNet18, self).__init__()

        self.conv1 = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=3, stride=3, padding=0),
            nn.BatchNorm2d(64)
        )
        # followed 4 blocks
        # [b, 64, h, w] => [b, 128, h ,w]
        self.blk1 = ResBlk(64, 128, stride=2)
        # [b, 128, h, w] => [b, 256, h, w]
        self.blk2 = ResBlk(128, 256, stride=2)
        # # [b, 256, h, w] => [b, 512, h, w]
        self.blk3 = ResBlk(256, 512, stride=2)
        # # [b, 512, h, w] => [b, 1024, h, w]
        self.blk4 = ResBlk(512, 512, stride=1)

        self.outlayer = nn.Linear(512*1*1, 11)

    def forward(self, x):
        """

        :param x:
        :return:
        """
        # print(x.shape)
        x = F.relu(self.conv1(x))
        # print(x.shape)
        # [b, 64, h, w] => [b, 1024, h, w]
        x = self.blk1(x)
        x = self.blk2(x)
        x = self.blk3(x)
        x = self.blk4(x)


        # print('after conv:', x.shape) #[b, 512, 2, 2]
        # [b, 512, h, w] => [b, 512, 1, 1]
        x = F.adaptive_avg_pool2d(x, [1, 1])
        # print('after pool:', x.shape)
        x = x.view(x.size(0), -1)
        x = self.outlayer(x)


        return x

# %%
epochs = 30
batch_sz = 256
lr = 0.001
iter_show = 1

train_ds = MyDataset(train_path, transform=train_transform , with_label=True)
train_loader = DataLoader(train_ds, batch_size=batch_sz, shuffle=True)

valid_ds = MyDataset(valid_path, transform=train_transform , with_label=True)
valid_loader = DataLoader(valid_ds, batch_size=batch_sz, shuffle=True)

# little_ds = MyDataset(little_path, transform=train_transform, with_label=True)
# little_loader = DataLoader(little_ds, batch_size=batch_sz, shuffle=True)
# train_ds = little_ds
# train_loader = little_loader
# valid_ds = little_ds
# valid_loader = little_loader

device = torch.device('cuda:0')
model = ResNet18().to(device)
criteon = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=lr)
# Out:
# class number: 11
# class number: 11

# %%
def train(epoch):
  model.train()
  for i, (features, labels) in enumerate(train_loader):
    features, labels = features.to(device), labels.to(device)
    logits = model(features)
    loss = criteon(logits, labels)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    preds = logits.argmax(dim=1)
    num_corrects = torch.eq(preds, labels).sum().float().item()
    accs = num_corrects / features.shape[0]
    if i % iter_show == 0:
      print("epoch [{:>2}/{}], iter [{:>2}/{}], loss {:.4f}, accuracy {:.4f}".format(epoch, epochs, i, len(train_ds)//batch_sz, loss.item(), accs))

def evaluate(epoch):
  model.eval()
  with torch.no_grad():
    total_num = 0
    total_correct = 0
    for x, label in valid_loader:
        x, label = x.to(device), label.to(device)
        logits = model(x)
        pred = logits.argmax(dim=1)
        total_correct += torch.eq(pred, label).float().sum().item()
        total_num += x.size(0)

    acc = total_correct / total_num
    print("epoch [{:>2}/{}], valid acc rate {:.4f}".format(epoch, epochs, acc))

# %%
for epoch in range(epochs):
  epoch_start_time = time.time()
  train(epoch)
  evaluate(epoch)
  print("epoch [{:>2}/{}] time {}".format(epoch, epochs, time.time() - epoch_start_time))
# Out:
# epoch [ 0/30], iter [ 0/38], loss 2.6089, accuracy 0.0312
# epoch [ 0/30], iter [ 1/38], loss 3.0924, accuracy 0.1797
# epoch [ 0/30], iter [ 2/38], loss 3.0874, accuracy 0.1992
# epoch [ 0/30], iter [ 3/38], loss 2.4689, accuracy 0.2109
# epoch [ 0/30], iter [ 4/38], loss 2.2533, accuracy 0.2305
# epoch [ 0/30], iter [ 5/38], loss 2.1737, accuracy 0.2031
# epoch [ 0/30], iter [ 6/38], loss 2.1851, accuracy 0.2031
# epoch [ 0/30], iter [ 7/38], loss 2.0306, accuracy 0.2461
# epoch [ 0/30], iter [ 8/38], loss 2.0550, accuracy 0.2969
# epoch [ 0/30], iter [ 9/38], loss 2.0351, accuracy 0.3047
# epoch [ 0/30], iter [10/38], loss 2.1056, accuracy 0.2656
# epoch [ 0/30], iter [11/38], loss 2.0160, accuracy 0.2812
# epoch [ 0/30], iter [12/38], loss 1.9812, accuracy 0.3398
# epoch [ 0/30], iter [13/38], loss 1.9780, accuracy 0.2969
# epoch [ 0/30], iter [14/38], loss 2.0461, accuracy 0.3008
# epoch [ 0/30], iter [15/38], loss 2.0334, accuracy 0.3242
# epoch [ 0/30], iter [16/38], loss 2.1002, accuracy 0.2656
# epoch [ 0/30], iter [17/38], loss 2.0045, accuracy 0.2852
# epoch [ 0/30], iter [18/38], loss 1.9584, accuracy 0.2891
# epoch [ 0/30], iter [19/38], loss 1.8978, accuracy 0.3555
# epoch [ 0/30], iter [20/38], loss 2.0295, accuracy 0.2578
# epoch [ 0/30], iter [21/38], loss 2.0014, accuracy 0.2852
# epoch [ 0/30], iter [22/38], loss 1.8021, accuracy 0.3750
# epoch [ 0/30], iter [23/38], loss 1.9480, accuracy 0.2773
# epoch [ 0/30], iter [24/38], loss 1.8674, accuracy 0.3438
# epoch [ 0/30], iter [25/38], loss 1.7961, accuracy 0.3477
# epoch [ 0/30], iter [26/38], loss 1.8413, accuracy 0.3867
# epoch [ 0/30], iter [27/38], loss 1.8888, accuracy 0.3359
# epoch [ 0/30], iter [28/38], loss 1.8240, accuracy 0.3555
# epoch [ 0/30], iter [29/38], loss 1.8221, accuracy 0.3633
# epoch [ 0/30], iter [30/38], loss 1.8714, accuracy 0.3477
# epoch [ 0/30], iter [31/38], loss 1.8224, accuracy 0.3672
# epoch [ 0/30], iter [32/38], loss 1.8841, accuracy 0.3711
# epoch [ 0/30], iter [33/38], loss 1.9249, accuracy 0.3164
# epoch [ 0/30], iter [34/38], loss 1.7441, accuracy 0.3555
# epoch [ 0/30], iter [35/38], loss 1.7768, accuracy 0.3516
# epoch [ 0/30], iter [36/38], loss 1.8047, accuracy 0.3711
# epoch [ 0/30], iter [37/38], loss 1.8585, accuracy 0.3867
# epoch [ 0/30], iter [38/38], loss 1.9795, accuracy 0.3478
# epoch [ 0/30], valid acc rate 0.1507
# epoch [ 0/30] time 89.84457039833069
# epoch [ 1/30], iter [ 0/38], loss 1.8390, accuracy 0.3555
# epoch [ 1/30], iter [ 1/38], loss 1.7357, accuracy 0.4102
# epoch [ 1/30], iter [ 2/38], loss 1.7767, accuracy 0.3906
# epoch [ 1/30], iter [ 3/38], loss 1.7832, accuracy 0.3867
# epoch [ 1/30], iter [ 4/38], loss 1.8390, accuracy 0.3789
# epoch [ 1/30], iter [ 5/38], loss 1.7241, accuracy 0.3672
# epoch [ 1/30], iter [ 6/38], loss 1.6562, accuracy 0.4609
# epoch [ 1/30], iter [ 7/38], loss 1.8430, accuracy 0.3789
# epoch [ 1/30], iter [ 8/38], loss 1.7603, accuracy 0.3945
# epoch [ 1/30], iter [ 9/38], loss 1.7172, accuracy 0.3828
# epoch [ 1/30], iter [10/38], loss 1.7187, accuracy 0.4141
# epoch [ 1/30], iter [11/38], loss 1.6271, accuracy 0.4492
# epoch [ 1/30], iter [12/38], loss 1.6909, accuracy 0.4180
# epoch [ 1/30], iter [13/38], loss 1.7266, accuracy 0.3945
# epoch [ 1/30], iter [14/38], loss 1.7410, accuracy 0.4023
# epoch [ 1/30], iter [15/38], loss 1.6114, accuracy 0.4531
# epoch [ 1/30], iter [16/38], loss 1.8053, accuracy 0.3281
# epoch [ 1/30], iter [17/38], loss 1.6303, accuracy 0.4570
# epoch [ 1/30], iter [18/38], loss 1.7411, accuracy 0.3750
# epoch [ 1/30], iter [19/38], loss 1.7307, accuracy 0.4102
# epoch [ 1/30], iter [20/38], loss 1.7359, accuracy 0.4023
# epoch [ 1/30], iter [21/38], loss 1.7976, accuracy 0.3789
# epoch [ 1/30], iter [22/38], loss 1.6417, accuracy 0.4141
# epoch [ 1/30], iter [23/38], loss 1.7285, accuracy 0.4062
# epoch [ 1/30], iter [24/38], loss 1.7835, accuracy 0.3594
# epoch [ 1/30], iter [25/38], loss 1.7275, accuracy 0.4023
# epoch [ 1/30], iter [26/38], loss 1.6579, accuracy 0.4414
# epoch [ 1/30], iter [27/38], loss 1.7631, accuracy 0.3906
# epoch [ 1/30], iter [28/38], loss 1.6602, accuracy 0.4141
# epoch [ 1/30], iter [29/38], loss 1.7733, accuracy 0.3945
# epoch [ 1/30], iter [30/38], loss 1.6309, accuracy 0.4023
# epoch [ 1/30], iter [31/38], loss 1.5964, accuracy 0.4141
# epoch [ 1/30], iter [32/38], loss 1.6476, accuracy 0.4805
# epoch [ 1/30], iter [33/38], loss 1.5498, accuracy 0.5039
# epoch [ 1/30], iter [34/38], loss 1.6529, accuracy 0.4414
# epoch [ 1/30], iter [35/38], loss 1.5789, accuracy 0.4297
# epoch [ 1/30], iter [36/38], loss 1.7072, accuracy 0.4258
# epoch [ 1/30], iter [37/38], loss 1.6683, accuracy 0.4180
# epoch [ 1/30], iter [38/38], loss 1.5557, accuracy 0.4783
# epoch [ 1/30], valid acc rate 0.3257
# epoch [ 1/30] time 89.93950247764587
# epoch [ 2/30], iter [ 0/38], loss 1.5498, accuracy 0.4688
# epoch [ 2/30], iter [ 1/38], loss 1.5928, accuracy 0.4258
# epoch [ 2/30], iter [ 2/38], loss 1.5416, accuracy 0.4648
# epoch [ 2/30], iter [ 3/38], loss 1.4842, accuracy 0.4922
# epoch [ 2/30], iter [ 4/38], loss 1.6222, accuracy 0.4375
# epoch [ 2/30], iter [ 5/38], loss 1.5096, accuracy 0.4805
# epoch [ 2/30], iter [ 6/38], loss 1.4715, accuracy 0.4609
# epoch [ 2/30], iter [ 7/38], loss 1.6301, accuracy 0.4922
# epoch [ 2/30], iter [ 8/38], loss 1.6515, accuracy 0.4648
# epoch [ 2/30], iter [ 9/38], loss 1.6713, accuracy 0.4219
# epoch [ 2/30], iter [10/38], loss 1.4720, accuracy 0.4766
# epoch [ 2/30], iter [11/38], loss 1.4739, accuracy 0.4844
# epoch [ 2/30], iter [12/38], loss 1.5684, accuracy 0.4453
# epoch [ 2/30], iter [13/38], loss 1.5933, accuracy 0.4688
# epoch [ 2/30], iter [14/38], loss 1.6043, accuracy 0.4258
# epoch [ 2/30], iter [15/38], loss 1.6088, accuracy 0.4688
# epoch [ 2/30], iter [16/38], loss 1.5074, accuracy 0.5391
# epoch [ 2/30], iter [17/38], loss 1.5885, accuracy 0.4688
# epoch [ 2/30], iter [18/38], loss 1.5185, accuracy 0.4727
# epoch [ 2/30], iter [19/38], loss 1.4871, accuracy 0.5156
# epoch [ 2/30], iter [20/38], loss 1.5509, accuracy 0.4453
# epoch [ 2/30], iter [21/38], loss 1.4966, accuracy 0.4492
# epoch [ 2/30], iter [22/38], loss 1.5319, accuracy 0.4688
# epoch [ 2/30], iter [23/38], loss 1.5218, accuracy 0.4453
# epoch [ 2/30], iter [24/38], loss 1.6080, accuracy 0.4453
# epoch [ 2/30], iter [25/38], loss 1.4839, accuracy 0.4844
# epoch [ 2/30], iter [26/38], loss 1.5593, accuracy 0.4570
# epoch [ 2/30], iter [27/38], loss 1.4936, accuracy 0.4883
# epoch [ 2/30], iter [28/38], loss 1.4809, accuracy 0.5078
# epoch [ 2/30], iter [29/38], loss 1.5736, accuracy 0.4570
# epoch [ 2/30], iter [30/38], loss 1.5974, accuracy 0.4805
# epoch [ 2/30], iter [31/38], loss 1.5166, accuracy 0.4531
# epoch [ 2/30], iter [32/38], loss 1.4888, accuracy 0.5039
# epoch [ 2/30], iter [33/38], loss 1.5516, accuracy 0.4766
# epoch [ 2/30], iter [34/38], loss 1.4906, accuracy 0.4688
# epoch [ 2/30], iter [35/38], loss 1.4379, accuracy 0.5078
# epoch [ 2/30], iter [36/38], loss 1.4252, accuracy 0.5312
# epoch [ 2/30], iter [37/38], loss 1.4889, accuracy 0.4727
# epoch [ 2/30], iter [38/38], loss 1.6071, accuracy 0.4130
# epoch [ 2/30], valid acc rate 0.4082
# epoch [ 2/30] time 89.58573722839355
# epoch [ 3/30], iter [ 0/38], loss 1.4491, accuracy 0.4961
# epoch [ 3/30], iter [ 1/38], loss 1.4326, accuracy 0.5156
# epoch [ 3/30], iter [ 2/38], loss 1.3371, accuracy 0.5547
# epoch [ 3/30], iter [ 3/38], loss 1.3551, accuracy 0.5039
# epoch [ 3/30], iter [ 4/38], loss 1.4388, accuracy 0.5039
# epoch [ 3/30], iter [ 5/38], loss 1.4144, accuracy 0.4922
# epoch [ 3/30], iter [ 6/38], loss 1.4943, accuracy 0.4570
# epoch [ 3/30], iter [ 7/38], loss 1.3821, accuracy 0.5391
# epoch [ 3/30], iter [ 8/38], loss 1.4295, accuracy 0.4727
# epoch [ 3/30], iter [ 9/38], loss 1.3719, accuracy 0.5664
# epoch [ 3/30], iter [10/38], loss 1.3347, accuracy 0.5664
# epoch [ 3/30], iter [11/38], loss 1.4964, accuracy 0.4922
# epoch [ 3/30], iter [12/38], loss 1.3629, accuracy 0.5273
# epoch [ 3/30], iter [13/38], loss 1.4204, accuracy 0.5273
# epoch [ 3/30], iter [14/38], loss 1.4010, accuracy 0.5156
# epoch [ 3/30], iter [15/38], loss 1.3476, accuracy 0.5312
# epoch [ 3/30], iter [16/38], loss 1.4333, accuracy 0.4922
# epoch [ 3/30], iter [17/38], loss 1.3895, accuracy 0.5391
# epoch [ 3/30], iter [18/38], loss 1.3647, accuracy 0.5430
# epoch [ 3/30], iter [19/38], loss 1.3662, accuracy 0.5508
# epoch [ 3/30], iter [20/38], loss 1.3291, accuracy 0.4883
# epoch [ 3/30], iter [21/38], loss 1.4416, accuracy 0.4922
# epoch [ 3/30], iter [22/38], loss 1.3522, accuracy 0.5547
# epoch [ 3/30], iter [23/38], loss 1.4224, accuracy 0.5156
# epoch [ 3/30], iter [24/38], loss 1.5211, accuracy 0.4961
# epoch [ 3/30], iter [25/38], loss 1.4454, accuracy 0.5000
# epoch [ 3/30], iter [26/38], loss 1.3311, accuracy 0.5586
# epoch [ 3/30], iter [27/38], loss 1.4888, accuracy 0.4844
# epoch [ 3/30], iter [28/38], loss 1.4647, accuracy 0.4922
# epoch [ 3/30], iter [29/38], loss 1.3755, accuracy 0.5469
# epoch [ 3/30], iter [30/38], loss 1.3386, accuracy 0.5625
# epoch [ 3/30], iter [31/38], loss 1.3986, accuracy 0.5195
# epoch [ 3/30], iter [32/38], loss 1.3530, accuracy 0.5234
# epoch [ 3/30], iter [33/38], loss 1.4459, accuracy 0.5117
# epoch [ 3/30], iter [34/38], loss 1.4059, accuracy 0.5078
# epoch [ 3/30], iter [35/38], loss 1.4414, accuracy 0.5117
# epoch [ 3/30], iter [36/38], loss 1.4389, accuracy 0.5000
# epoch [ 3/30], iter [37/38], loss 1.3387, accuracy 0.5547
# epoch [ 3/30], iter [38/38], loss 1.2709, accuracy 0.5435
# epoch [ 3/30], valid acc rate 0.3822
# epoch [ 3/30] time 89.6510443687439
# epoch [ 4/30], iter [ 0/38], loss 1.3643, accuracy 0.5195
# epoch [ 4/30], iter [ 1/38], loss 1.3254, accuracy 0.5430
# epoch [ 4/30], iter [ 2/38], loss 1.4116, accuracy 0.5391
# epoch [ 4/30], iter [ 3/38], loss 1.2669, accuracy 0.5781
# epoch [ 4/30], iter [ 4/38], loss 1.2302, accuracy 0.6016
# epoch [ 4/30], iter [ 5/38], loss 1.2356, accuracy 0.5859
# epoch [ 4/30], iter [ 6/38], loss 1.2955, accuracy 0.5273
# epoch [ 4/30], iter [ 7/38], loss 1.3388, accuracy 0.5547
# epoch [ 4/30], iter [ 8/38], loss 1.2584, accuracy 0.5742
# epoch [ 4/30], iter [ 9/38], loss 1.2792, accuracy 0.5781
# epoch [ 4/30], iter [10/38], loss 1.1846, accuracy 0.6016
# epoch [ 4/30], iter [11/38], loss 1.3318, accuracy 0.5312
# epoch [ 4/30], iter [12/38], loss 1.3051, accuracy 0.5352
# epoch [ 4/30], iter [13/38], loss 1.2646, accuracy 0.5742
# epoch [ 4/30], iter [14/38], loss 1.2776, accuracy 0.5625
# epoch [ 4/30], iter [15/38], loss 1.2255, accuracy 0.5664
# epoch [ 4/30], iter [16/38], loss 1.3212, accuracy 0.5273
# epoch [ 4/30], iter [17/38], loss 1.2729, accuracy 0.5508
# epoch [ 4/30], iter [18/38], loss 1.2661, accuracy 0.5430
# epoch [ 4/30], iter [19/38], loss 1.1446, accuracy 0.6094
# epoch [ 4/30], iter [20/38], loss 1.1690, accuracy 0.5703
# epoch [ 4/30], iter [21/38], loss 1.2165, accuracy 0.5742
# epoch [ 4/30], iter [22/38], loss 1.3556, accuracy 0.5781
# epoch [ 4/30], iter [23/38], loss 1.2416, accuracy 0.5820
# epoch [ 4/30], iter [24/38], loss 1.1917, accuracy 0.6016
# epoch [ 4/30], iter [25/38], loss 1.3134, accuracy 0.5508
# epoch [ 4/30], iter [26/38], loss 1.3842, accuracy 0.5273
# epoch [ 4/30], iter [27/38], loss 1.3156, accuracy 0.5469
# epoch [ 4/30], iter [28/38], loss 1.1293, accuracy 0.6367
# epoch [ 4/30], iter [29/38], loss 1.2759, accuracy 0.5195
# epoch [ 4/30], iter [30/38], loss 1.1821, accuracy 0.5703
# epoch [ 4/30], iter [31/38], loss 1.3950, accuracy 0.5117
# epoch [ 4/30], iter [32/38], loss 1.2765, accuracy 0.5508
# epoch [ 4/30], iter [33/38], loss 1.1401, accuracy 0.6250
# epoch [ 4/30], iter [34/38], loss 1.2170, accuracy 0.5508
# epoch [ 4/30], iter [35/38], loss 1.1960, accuracy 0.5469
# epoch [ 4/30], iter [36/38], loss 1.2526, accuracy 0.5430
# epoch [ 4/30], iter [37/38], loss 1.3020, accuracy 0.5625
# epoch [ 4/30], iter [38/38], loss 1.3757, accuracy 0.5652
# epoch [ 4/30], valid acc rate 0.3700
# epoch [ 4/30] time 89.67457580566406
# epoch [ 5/30], iter [ 0/38], loss 1.1637, accuracy 0.5977
# epoch [ 5/30], iter [ 1/38], loss 1.2050, accuracy 0.6016
# epoch [ 5/30], iter [ 2/38], loss 1.1005, accuracy 0.6172
# epoch [ 5/30], iter [ 3/38], loss 1.1850, accuracy 0.5898
# epoch [ 5/30], iter [ 4/38], loss 1.0408, accuracy 0.6211
# epoch [ 5/30], iter [ 5/38], loss 1.2185, accuracy 0.5664
# epoch [ 5/30], iter [ 6/38], loss 1.0434, accuracy 0.6875
# epoch [ 5/30], iter [ 7/38], loss 1.1574, accuracy 0.5742
# epoch [ 5/30], iter [ 8/38], loss 1.1779, accuracy 0.6211
# epoch [ 5/30], iter [ 9/38], loss 1.1231, accuracy 0.5781
# epoch [ 5/30], iter [10/38], loss 1.1136, accuracy 0.6328
# epoch [ 5/30], iter [11/38], loss 1.1578, accuracy 0.5977
# epoch [ 5/30], iter [12/38], loss 1.1070, accuracy 0.6562
# epoch [ 5/30], iter [13/38], loss 1.1688, accuracy 0.5820
# epoch [ 5/30], iter [14/38], loss 1.1689, accuracy 0.5859
# epoch [ 5/30], iter [15/38], loss 1.2244, accuracy 0.6094
# epoch [ 5/30], iter [16/38], loss 1.0800, accuracy 0.6719
# epoch [ 5/30], iter [17/38], loss 1.2716, accuracy 0.5625
# epoch [ 5/30], iter [18/38], loss 1.2790, accuracy 0.5664
# epoch [ 5/30], iter [19/38], loss 1.1554, accuracy 0.6094
# epoch [ 5/30], iter [20/38], loss 1.1263, accuracy 0.5859
# epoch [ 5/30], iter [21/38], loss 1.1646, accuracy 0.5664
# epoch [ 5/30], iter [22/38], loss 1.1455, accuracy 0.6055
# epoch [ 5/30], iter [23/38], loss 1.1477, accuracy 0.6016
# epoch [ 5/30], iter [24/38], loss 1.1523, accuracy 0.5938
# epoch [ 5/30], iter [25/38], loss 1.1008, accuracy 0.6016
# epoch [ 5/30], iter [26/38], loss 1.1478, accuracy 0.6055
# epoch [ 5/30], iter [27/38], loss 1.2854, accuracy 0.5742
# epoch [ 5/30], iter [28/38], loss 1.2498, accuracy 0.5547
# epoch [ 5/30], iter [29/38], loss 1.0516, accuracy 0.6289
# epoch [ 5/30], iter [30/38], loss 1.1616, accuracy 0.5938
# epoch [ 5/30], iter [31/38], loss 1.1510, accuracy 0.6055
# epoch [ 5/30], iter [32/38], loss 1.0684, accuracy 0.6367
# epoch [ 5/30], iter [33/38], loss 1.2722, accuracy 0.5781
# epoch [ 5/30], iter [34/38], loss 1.0642, accuracy 0.6328
# epoch [ 5/30], iter [35/38], loss 1.2011, accuracy 0.5781
# epoch [ 5/30], iter [36/38], loss 1.2196, accuracy 0.5898
# epoch [ 5/30], iter [37/38], loss 1.0472, accuracy 0.6367
# epoch [ 5/30], iter [38/38], loss 1.1824, accuracy 0.5725
# epoch [ 5/30], valid acc rate 0.4950
# epoch [ 5/30] time 90.10742282867432
# epoch [ 6/30], iter [ 0/38], loss 0.9813, accuracy 0.6914
# epoch [ 6/30], iter [ 1/38], loss 0.9214, accuracy 0.7031
# epoch [ 6/30], iter [ 2/38], loss 1.0472, accuracy 0.6641
# epoch [ 6/30], iter [ 3/38], loss 0.8840, accuracy 0.7266
# epoch [ 6/30], iter [ 4/38], loss 1.0527, accuracy 0.6680
# epoch [ 6/30], iter [ 5/38], loss 1.1202, accuracy 0.5977
# epoch [ 6/30], iter [ 6/38], loss 1.0824, accuracy 0.6172
# epoch [ 6/30], iter [ 7/38], loss 1.1675, accuracy 0.5820
# epoch [ 6/30], iter [ 8/38], loss 0.9600, accuracy 0.6680
# epoch [ 6/30], iter [ 9/38], loss 1.0419, accuracy 0.6250
# epoch [ 6/30], iter [10/38], loss 1.0176, accuracy 0.6094
# epoch [ 6/30], iter [11/38], loss 0.8692, accuracy 0.7109
# epoch [ 6/30], iter [12/38], loss 0.9871, accuracy 0.6484
# epoch [ 6/30], iter [13/38], loss 1.0177, accuracy 0.6719
# epoch [ 6/30], iter [14/38], loss 1.0008, accuracy 0.6797
# epoch [ 6/30], iter [15/38], loss 1.2140, accuracy 0.5938
# epoch [ 6/30], iter [16/38], loss 1.0135, accuracy 0.6445
# epoch [ 6/30], iter [17/38], loss 1.0608, accuracy 0.6367
# epoch [ 6/30], iter [18/38], loss 1.1223, accuracy 0.6172
# epoch [ 6/30], iter [19/38], loss 1.0557, accuracy 0.6367
# epoch [ 6/30], iter [20/38], loss 1.0581, accuracy 0.6523
# epoch [ 6/30], iter [21/38], loss 0.9949, accuracy 0.6680
# epoch [ 6/30], iter [22/38], loss 0.9573, accuracy 0.6406
# epoch [ 6/30], iter [23/38], loss 1.0515, accuracy 0.6328
# epoch [ 6/30], iter [24/38], loss 1.1159, accuracy 0.5938
# epoch [ 6/30], iter [25/38], loss 1.0253, accuracy 0.6602
# epoch [ 6/30], iter [26/38], loss 1.0852, accuracy 0.5781
# epoch [ 6/30], iter [27/38], loss 1.0511, accuracy 0.5938
# epoch [ 6/30], iter [28/38], loss 1.0501, accuracy 0.6523
# epoch [ 6/30], iter [29/38], loss 1.0263, accuracy 0.6445
# epoch [ 6/30], iter [30/38], loss 0.9481, accuracy 0.6680
# epoch [ 6/30], iter [31/38], loss 1.0001, accuracy 0.6836
# epoch [ 6/30], iter [32/38], loss 0.9856, accuracy 0.6484
# epoch [ 6/30], iter [33/38], loss 1.0525, accuracy 0.6445
# epoch [ 6/30], iter [34/38], loss 0.9040, accuracy 0.7109
# epoch [ 6/30], iter [35/38], loss 1.0101, accuracy 0.6719
# epoch [ 6/30], iter [36/38], loss 1.0632, accuracy 0.6211
# epoch [ 6/30], iter [37/38], loss 1.0095, accuracy 0.6367
# epoch [ 6/30], iter [38/38], loss 1.0822, accuracy 0.6087
# epoch [ 6/30], valid acc rate 0.4854
# epoch [ 6/30] time 89.59074521064758
# epoch [ 7/30], iter [ 0/38], loss 0.9511, accuracy 0.6484
# epoch [ 7/30], iter [ 1/38], loss 0.9227, accuracy 0.6602
# epoch [ 7/30], iter [ 2/38], loss 0.9409, accuracy 0.7070
# epoch [ 7/30], iter [ 3/38], loss 0.9403, accuracy 0.6836
# epoch [ 7/30], iter [ 4/38], loss 0.8676, accuracy 0.6992
# epoch [ 7/30], iter [ 5/38], loss 0.8703, accuracy 0.7227
# epoch [ 7/30], iter [ 6/38], loss 0.8564, accuracy 0.6992
# epoch [ 7/30], iter [ 7/38], loss 0.9671, accuracy 0.6641
# epoch [ 7/30], iter [ 8/38], loss 0.8209, accuracy 0.7266
# epoch [ 7/30], iter [ 9/38], loss 0.9614, accuracy 0.6641
# epoch [ 7/30], iter [10/38], loss 0.9295, accuracy 0.6836
# epoch [ 7/30], iter [11/38], loss 0.9725, accuracy 0.6836
# epoch [ 7/30], iter [12/38], loss 0.9462, accuracy 0.6914
# epoch [ 7/30], iter [13/38], loss 1.0508, accuracy 0.6211
# epoch [ 7/30], iter [14/38], loss 0.8133, accuracy 0.7188
# epoch [ 7/30], iter [15/38], loss 0.8470, accuracy 0.6914
# epoch [ 7/30], iter [16/38], loss 0.8697, accuracy 0.7109
# epoch [ 7/30], iter [17/38], loss 0.7554, accuracy 0.7461
# epoch [ 7/30], iter [18/38], loss 0.9658, accuracy 0.6406
# epoch [ 7/30], iter [19/38], loss 0.9594, accuracy 0.6758
# epoch [ 7/30], iter [20/38], loss 0.9531, accuracy 0.6406
# epoch [ 7/30], iter [21/38], loss 0.9353, accuracy 0.6680
# epoch [ 7/30], iter [22/38], loss 0.9223, accuracy 0.6602
# epoch [ 7/30], iter [23/38], loss 0.8484, accuracy 0.7344
# epoch [ 7/30], iter [24/38], loss 0.8478, accuracy 0.7070
# epoch [ 7/30], iter [25/38], loss 0.9105, accuracy 0.7031
# epoch [ 7/30], iter [26/38], loss 1.0120, accuracy 0.6523
# epoch [ 7/30], iter [27/38], loss 0.9528, accuracy 0.6562
# epoch [ 7/30], iter [28/38], loss 0.9782, accuracy 0.6719
# epoch [ 7/30], iter [29/38], loss 0.9580, accuracy 0.6562
# epoch [ 7/30], iter [30/38], loss 0.9680, accuracy 0.6836
# epoch [ 7/30], iter [31/38], loss 0.9268, accuracy 0.6680
# epoch [ 7/30], iter [32/38], loss 0.8703, accuracy 0.6953
# epoch [ 7/30], iter [33/38], loss 0.8913, accuracy 0.6953
# epoch [ 7/30], iter [34/38], loss 0.7503, accuracy 0.7422
# epoch [ 7/30], iter [35/38], loss 0.9728, accuracy 0.6641
# epoch [ 7/30], iter [36/38], loss 0.9298, accuracy 0.6797
# epoch [ 7/30], iter [37/38], loss 0.9425, accuracy 0.6602
# epoch [ 7/30], iter [38/38], loss 0.8915, accuracy 0.6522
# epoch [ 7/30], valid acc rate 0.5516
# epoch [ 7/30] time 89.50067067146301
# epoch [ 8/30], iter [ 0/38], loss 0.7455, accuracy 0.7422
# epoch [ 8/30], iter [ 1/38], loss 0.7637, accuracy 0.7539
# epoch [ 8/30], iter [ 2/38], loss 0.8418, accuracy 0.7305
# epoch [ 8/30], iter [ 3/38], loss 0.7583, accuracy 0.7227
# epoch [ 8/30], iter [ 4/38], loss 0.7239, accuracy 0.7383
# epoch [ 8/30], iter [ 5/38], loss 0.6916, accuracy 0.7422
# epoch [ 8/30], iter [ 6/38], loss 0.6908, accuracy 0.7656
# epoch [ 8/30], iter [ 7/38], loss 0.7542, accuracy 0.7500
# epoch [ 8/30], iter [ 8/38], loss 0.7677, accuracy 0.7109
# epoch [ 8/30], iter [ 9/38], loss 0.8384, accuracy 0.7109
# epoch [ 8/30], iter [10/38], loss 0.7230, accuracy 0.7578
# epoch [ 8/30], iter [11/38], loss 0.7272, accuracy 0.7305
# epoch [ 8/30], iter [12/38], loss 0.6843, accuracy 0.7812
# epoch [ 8/30], iter [13/38], loss 0.5934, accuracy 0.7773
# epoch [ 8/30], iter [14/38], loss 0.7170, accuracy 0.7812
# epoch [ 8/30], iter [15/38], loss 0.7733, accuracy 0.7422
# epoch [ 8/30], iter [16/38], loss 0.7119, accuracy 0.7422
# epoch [ 8/30], iter [17/38], loss 0.7119, accuracy 0.7305
# epoch [ 8/30], iter [18/38], loss 0.7795, accuracy 0.7344
# epoch [ 8/30], iter [19/38], loss 0.5883, accuracy 0.7891
# epoch [ 8/30], iter [20/38], loss 0.7245, accuracy 0.7305
# epoch [ 8/30], iter [21/38], loss 0.6773, accuracy 0.7773
# epoch [ 8/30], iter [22/38], loss 0.7329, accuracy 0.7539
# epoch [ 8/30], iter [23/38], loss 0.6748, accuracy 0.7656
# epoch [ 8/30], iter [24/38], loss 0.8161, accuracy 0.7109
# epoch [ 8/30], iter [25/38], loss 0.8030, accuracy 0.7109
# epoch [ 8/30], iter [26/38], loss 0.9035, accuracy 0.6953
# epoch [ 8/30], iter [27/38], loss 0.8148, accuracy 0.7070
# epoch [ 8/30], iter [28/38], loss 0.8068, accuracy 0.6914
# epoch [ 8/30], iter [29/38], loss 0.6752, accuracy 0.7734
# epoch [ 8/30], iter [30/38], loss 0.6294, accuracy 0.7930
# epoch [ 8/30], iter [31/38], loss 0.8690, accuracy 0.7031
# epoch [ 8/30], iter [32/38], loss 0.7897, accuracy 0.7422
# epoch [ 8/30], iter [33/38], loss 0.7139, accuracy 0.7617
# epoch [ 8/30], iter [34/38], loss 0.7086, accuracy 0.7656
# epoch [ 8/30], iter [35/38], loss 0.7648, accuracy 0.7344
# epoch [ 8/30], iter [36/38], loss 0.8907, accuracy 0.6523
# epoch [ 8/30], iter [37/38], loss 0.7946, accuracy 0.7188
# epoch [ 8/30], iter [38/38], loss 0.6919, accuracy 0.7319
# epoch [ 8/30], valid acc rate 0.4641
# epoch [ 8/30] time 89.804856300354
# epoch [ 9/30], iter [ 0/38], loss 0.6435, accuracy 0.7773
# epoch [ 9/30], iter [ 1/38], loss 0.5745, accuracy 0.7969
# epoch [ 9/30], iter [ 2/38], loss 0.5881, accuracy 0.8203
# epoch [ 9/30], iter [ 3/38], loss 0.6104, accuracy 0.7891
# epoch [ 9/30], iter [ 4/38], loss 0.6313, accuracy 0.8242
# epoch [ 9/30], iter [ 5/38], loss 0.6583, accuracy 0.7852
# epoch [ 9/30], iter [ 6/38], loss 0.6476, accuracy 0.7969
# epoch [ 9/30], iter [ 7/38], loss 0.5364, accuracy 0.8320
# epoch [ 9/30], iter [ 8/38], loss 0.5429, accuracy 0.8320
# epoch [ 9/30], iter [ 9/38], loss 0.5033, accuracy 0.8477
# epoch [ 9/30], iter [10/38], loss 0.5926, accuracy 0.8086
# epoch [ 9/30], iter [11/38], loss 0.5541, accuracy 0.8047
# epoch [ 9/30], iter [12/38], loss 0.3848, accuracy 0.8828
# epoch [ 9/30], iter [13/38], loss 0.5057, accuracy 0.8359
# epoch [ 9/30], iter [14/38], loss 0.6291, accuracy 0.7578
# epoch [ 9/30], iter [15/38], loss 0.4544, accuracy 0.8477
# epoch [ 9/30], iter [16/38], loss 0.6436, accuracy 0.7734
# epoch [ 9/30], iter [17/38], loss 0.5873, accuracy 0.8086
# epoch [ 9/30], iter [18/38], loss 0.5142, accuracy 0.8398
# epoch [ 9/30], iter [19/38], loss 0.5102, accuracy 0.8164
# epoch [ 9/30], iter [20/38], loss 0.6538, accuracy 0.7773
# epoch [ 9/30], iter [21/38], loss 0.6682, accuracy 0.7578
# epoch [ 9/30], iter [22/38], loss 0.6444, accuracy 0.8047
# epoch [ 9/30], iter [23/38], loss 0.5715, accuracy 0.8008
# epoch [ 9/30], iter [24/38], loss 0.6610, accuracy 0.7734
# epoch [ 9/30], iter [25/38], loss 0.6976, accuracy 0.7500
# epoch [ 9/30], iter [26/38], loss 0.5613, accuracy 0.8047
# epoch [ 9/30], iter [27/38], loss 0.6375, accuracy 0.8047
# epoch [ 9/30], iter [28/38], loss 0.5791, accuracy 0.8008
# epoch [ 9/30], iter [29/38], loss 0.6273, accuracy 0.7812
# epoch [ 9/30], iter [30/38], loss 0.5922, accuracy 0.7891
# epoch [ 9/30], iter [31/38], loss 0.5909, accuracy 0.8164
# epoch [ 9/30], iter [32/38], loss 0.7218, accuracy 0.7500
# epoch [ 9/30], iter [33/38], loss 0.6154, accuracy 0.7773
# epoch [ 9/30], iter [34/38], loss 0.5533, accuracy 0.8203
# epoch [ 9/30], iter [35/38], loss 0.5631, accuracy 0.8125
# epoch [ 9/30], iter [36/38], loss 0.5059, accuracy 0.8438
# epoch [ 9/30], iter [37/38], loss 0.6848, accuracy 0.7344
# epoch [ 9/30], iter [38/38], loss 0.7099, accuracy 0.7391
# epoch [ 9/30], valid acc rate 0.5598
# epoch [ 9/30] time 89.45074653625488
# epoch [10/30], iter [ 0/38], loss 0.3784, accuracy 0.8984
# epoch [10/30], iter [ 1/38], loss 0.3937, accuracy 0.8555
# epoch [10/30], iter [ 2/38], loss 0.4295, accuracy 0.8672
# epoch [10/30], iter [ 3/38], loss 0.4543, accuracy 0.8477
# epoch [10/30], iter [ 4/38], loss 0.4272, accuracy 0.8633
# epoch [10/30], iter [ 5/38], loss 0.3784, accuracy 0.8945
# epoch [10/30], iter [ 6/38], loss 0.3477, accuracy 0.8906
# epoch [10/30], iter [ 7/38], loss 0.4778, accuracy 0.8438
# epoch [10/30], iter [ 8/38], loss 0.5068, accuracy 0.8438
# epoch [10/30], iter [ 9/38], loss 0.4556, accuracy 0.8672
# epoch [10/30], iter [10/38], loss 0.4391, accuracy 0.8516
# epoch [10/30], iter [11/38], loss 0.3774, accuracy 0.8867
# epoch [10/30], iter [12/38], loss 0.3624, accuracy 0.8906
# epoch [10/30], iter [13/38], loss 0.3863, accuracy 0.8828
# epoch [10/30], iter [14/38], loss 0.4354, accuracy 0.8398
# epoch [10/30], iter [15/38], loss 0.3168, accuracy 0.9023
# epoch [10/30], iter [16/38], loss 0.5387, accuracy 0.8359
# epoch [10/30], iter [17/38], loss 0.3960, accuracy 0.8828
# epoch [10/30], iter [18/38], loss 0.4358, accuracy 0.8633
# epoch [10/30], iter [19/38], loss 0.3150, accuracy 0.8867
# epoch [10/30], iter [20/38], loss 0.4485, accuracy 0.8516
# epoch [10/30], iter [21/38], loss 0.3746, accuracy 0.8711
# epoch [10/30], iter [22/38], loss 0.3994, accuracy 0.8789
# epoch [10/30], iter [23/38], loss 0.4098, accuracy 0.8398
# epoch [10/30], iter [24/38], loss 0.3518, accuracy 0.8789
# epoch [10/30], iter [25/38], loss 0.4832, accuracy 0.8438
# epoch [10/30], iter [26/38], loss 0.4029, accuracy 0.8672
# epoch [10/30], iter [27/38], loss 0.3957, accuracy 0.8555
# epoch [10/30], iter [28/38], loss 0.5238, accuracy 0.8164
# epoch [10/30], iter [29/38], loss 0.3738, accuracy 0.8789
# epoch [10/30], iter [30/38], loss 0.4429, accuracy 0.8516
# epoch [10/30], iter [31/38], loss 0.4171, accuracy 0.8555
# epoch [10/30], iter [32/38], loss 0.4025, accuracy 0.8789
# epoch [10/30], iter [33/38], loss 0.3700, accuracy 0.8828
# epoch [10/30], iter [34/38], loss 0.5114, accuracy 0.8477
# epoch [10/30], iter [35/38], loss 0.3928, accuracy 0.8711
# epoch [10/30], iter [36/38], loss 0.4158, accuracy 0.8477
# epoch [10/30], iter [37/38], loss 0.5227, accuracy 0.8086
# epoch [10/30], iter [38/38], loss 0.4279, accuracy 0.8478
# epoch [10/30], valid acc rate 0.4397
# epoch [10/30] time 90.01092195510864
# epoch [11/30], iter [ 0/38], loss 0.2713, accuracy 0.9102
# epoch [11/30], iter [ 1/38], loss 0.4238, accuracy 0.8594
# epoch [11/30], iter [ 2/38], loss 0.3913, accuracy 0.8672
# epoch [11/30], iter [ 3/38], loss 0.3963, accuracy 0.8477
# epoch [11/30], iter [ 4/38], loss 0.2815, accuracy 0.8984
# epoch [11/30], iter [ 5/38], loss 0.2684, accuracy 0.9141
# epoch [11/30], iter [ 6/38], loss 0.4004, accuracy 0.8906
# epoch [11/30], iter [ 7/38], loss 0.3136, accuracy 0.8984
# epoch [11/30], iter [ 8/38], loss 0.2662, accuracy 0.9219
# epoch [11/30], iter [ 9/38], loss 0.2832, accuracy 0.9102
# epoch [11/30], iter [10/38], loss 0.3468, accuracy 0.8555
# epoch [11/30], iter [11/38], loss 0.3419, accuracy 0.8750
# epoch [11/30], iter [12/38], loss 0.3375, accuracy 0.8750
# epoch [11/30], iter [13/38], loss 0.2578, accuracy 0.9180
# epoch [11/30], iter [14/38], loss 0.4058, accuracy 0.8594
# epoch [11/30], iter [15/38], loss 0.3501, accuracy 0.8906
# epoch [11/30], iter [16/38], loss 0.3663, accuracy 0.8750
# epoch [11/30], iter [17/38], loss 0.3296, accuracy 0.8789
# epoch [11/30], iter [18/38], loss 0.3059, accuracy 0.9062
# epoch [11/30], iter [19/38], loss 0.3470, accuracy 0.8828
# epoch [11/30], iter [20/38], loss 0.3811, accuracy 0.8867
# epoch [11/30], iter [21/38], loss 0.3139, accuracy 0.9062
# epoch [11/30], iter [22/38], loss 0.3466, accuracy 0.8984
# epoch [11/30], iter [23/38], loss 0.4568, accuracy 0.8594
# epoch [11/30], iter [24/38], loss 0.3263, accuracy 0.8789
# epoch [11/30], iter [25/38], loss 0.3450, accuracy 0.8750
# epoch [11/30], iter [26/38], loss 0.3209, accuracy 0.9023
# epoch [11/30], iter [27/38], loss 0.4235, accuracy 0.8398
# epoch [11/30], iter [28/38], loss 0.3516, accuracy 0.8945
# epoch [11/30], iter [29/38], loss 0.3089, accuracy 0.8906
# epoch [11/30], iter [30/38], loss 0.3651, accuracy 0.8906
# epoch [11/30], iter [31/38], loss 0.3448, accuracy 0.8945
# epoch [11/30], iter [32/38], loss 0.3934, accuracy 0.8828
# epoch [11/30], iter [33/38], loss 0.4147, accuracy 0.8828
# epoch [11/30], iter [34/38], loss 0.2798, accuracy 0.8945
# epoch [11/30], iter [35/38], loss 0.3457, accuracy 0.8867
# epoch [11/30], iter [36/38], loss 0.3361, accuracy 0.8750
# epoch [11/30], iter [37/38], loss 0.3196, accuracy 0.8945
# epoch [11/30], iter [38/38], loss 0.2734, accuracy 0.9348
# epoch [11/30], valid acc rate 0.4213
# epoch [11/30] time 90.53804183006287
# epoch [12/30], iter [ 0/38], loss 0.2309, accuracy 0.9180
# epoch [12/30], iter [ 1/38], loss 0.1955, accuracy 0.9414
# epoch [12/30], iter [ 2/38], loss 0.3059, accuracy 0.9062
# epoch [12/30], iter [ 3/38], loss 0.2012, accuracy 0.9414
# epoch [12/30], iter [ 4/38], loss 0.2287, accuracy 0.9375
# epoch [12/30], iter [ 5/38], loss 0.2744, accuracy 0.9219
# epoch [12/30], iter [ 6/38], loss 0.2988, accuracy 0.9062
# epoch [12/30], iter [ 7/38], loss 0.2576, accuracy 0.9375
# epoch [12/30], iter [ 8/38], loss 0.2678, accuracy 0.9062
# epoch [12/30], iter [ 9/38], loss 0.2686, accuracy 0.9219
# epoch [12/30], iter [10/38], loss 0.2315, accuracy 0.9375
# epoch [12/30], iter [11/38], loss 0.2757, accuracy 0.8828
# epoch [12/30], iter [12/38], loss 0.2553, accuracy 0.9180
# epoch [12/30], iter [13/38], loss 0.1911, accuracy 0.9414
# epoch [12/30], iter [14/38], loss 0.1872, accuracy 0.9570
# epoch [12/30], iter [15/38], loss 0.2403, accuracy 0.9258
# epoch [12/30], iter [16/38], loss 0.2000, accuracy 0.9531
# epoch [12/30], iter [17/38], loss 0.2419, accuracy 0.9180
# epoch [12/30], iter [18/38], loss 0.3449, accuracy 0.8984
# epoch [12/30], iter [19/38], loss 0.1915, accuracy 0.9336
# epoch [12/30], iter [20/38], loss 0.1930, accuracy 0.9414
# epoch [12/30], iter [21/38], loss 0.1979, accuracy 0.9453
# epoch [12/30], iter [22/38], loss 0.2623, accuracy 0.9023
# epoch [12/30], iter [23/38], loss 0.2180, accuracy 0.9297
# epoch [12/30], iter [24/38], loss 0.2297, accuracy 0.9414
# epoch [12/30], iter [25/38], loss 0.1895, accuracy 0.9297
# epoch [12/30], iter [26/38], loss 0.1775, accuracy 0.9375
# epoch [12/30], iter [27/38], loss 0.2158, accuracy 0.9414
# epoch [12/30], iter [28/38], loss 0.2136, accuracy 0.9141
# epoch [12/30], iter [29/38], loss 0.2330, accuracy 0.9336
# epoch [12/30], iter [30/38], loss 0.2175, accuracy 0.9375
# epoch [12/30], iter [31/38], loss 0.2627, accuracy 0.9102
# epoch [12/30], iter [32/38], loss 0.2170, accuracy 0.9414
# epoch [12/30], iter [33/38], loss 0.1799, accuracy 0.9570
# epoch [12/30], iter [34/38], loss 0.2331, accuracy 0.9180
# epoch [12/30], iter [35/38], loss 0.2873, accuracy 0.9102
# epoch [12/30], iter [36/38], loss 0.2432, accuracy 0.9258
# epoch [12/30], iter [37/38], loss 0.2343, accuracy 0.9141
# epoch [12/30], iter [38/38], loss 0.1642, accuracy 0.9493
# epoch [12/30], valid acc rate 0.5108
# epoch [12/30] time 89.89411520957947
# epoch [13/30], iter [ 0/38], loss 0.1118, accuracy 0.9609
# epoch [13/30], iter [ 1/38], loss 0.1897, accuracy 0.9297
# epoch [13/30], iter [ 2/38], loss 0.1683, accuracy 0.9414
# epoch [13/30], iter [ 3/38], loss 0.1321, accuracy 0.9648
# epoch [13/30], iter [ 4/38], loss 0.1280, accuracy 0.9609
# epoch [13/30], iter [ 5/38], loss 0.2187, accuracy 0.9336
# epoch [13/30], iter [ 6/38], loss 0.1754, accuracy 0.9492
# epoch [13/30], iter [ 7/38], loss 0.1598, accuracy 0.9570
# epoch [13/30], iter [ 8/38], loss 0.2106, accuracy 0.9180
# epoch [13/30], iter [ 9/38], loss 0.1499, accuracy 0.9531
# epoch [13/30], iter [10/38], loss 0.1312, accuracy 0.9648
# epoch [13/30], iter [11/38], loss 0.1540, accuracy 0.9531
# epoch [13/30], iter [12/38], loss 0.1512, accuracy 0.9453
# epoch [13/30], iter [13/38], loss 0.1367, accuracy 0.9688
# epoch [13/30], iter [14/38], loss 0.0993, accuracy 0.9805
# epoch [13/30], iter [15/38], loss 0.1169, accuracy 0.9648
# epoch [13/30], iter [16/38], loss 0.1315, accuracy 0.9609
# epoch [13/30], iter [17/38], loss 0.1444, accuracy 0.9609
# epoch [13/30], iter [18/38], loss 0.1724, accuracy 0.9297
# epoch [13/30], iter [19/38], loss 0.1246, accuracy 0.9609
# epoch [13/30], iter [20/38], loss 0.1143, accuracy 0.9648
# epoch [13/30], iter [21/38], loss 0.1846, accuracy 0.9492
# epoch [13/30], iter [22/38], loss 0.1169, accuracy 0.9648
# epoch [13/30], iter [23/38], loss 0.1223, accuracy 0.9648
# epoch [13/30], iter [24/38], loss 0.1246, accuracy 0.9570
# epoch [13/30], iter [25/38], loss 0.1196, accuracy 0.9648
# epoch [13/30], iter [26/38], loss 0.1458, accuracy 0.9648
# epoch [13/30], iter [27/38], loss 0.1198, accuracy 0.9727
# epoch [13/30], iter [28/38], loss 0.1094, accuracy 0.9727
# epoch [13/30], iter [29/38], loss 0.1526, accuracy 0.9492
# epoch [13/30], iter [30/38], loss 0.1254, accuracy 0.9688
# epoch [13/30], iter [31/38], loss 0.1632, accuracy 0.9375
# epoch [13/30], iter [32/38], loss 0.1456, accuracy 0.9453
# epoch [13/30], iter [33/38], loss 0.0848, accuracy 0.9805
# epoch [13/30], iter [34/38], loss 0.1415, accuracy 0.9492
# epoch [13/30], iter [35/38], loss 0.1428, accuracy 0.9570
# epoch [13/30], iter [36/38], loss 0.1596, accuracy 0.9531
# epoch [13/30], iter [37/38], loss 0.1252, accuracy 0.9609
# epoch [13/30], iter [38/38], loss 0.1047, accuracy 0.9710
# epoch [13/30], valid acc rate 0.5478
# epoch [13/30] time 89.36095881462097
# epoch [14/30], iter [ 0/38], loss 0.0940, accuracy 0.9648
# epoch [14/30], iter [ 1/38], loss 0.0980, accuracy 0.9805
# epoch [14/30], iter [ 2/38], loss 0.0684, accuracy 0.9883
# epoch [14/30], iter [ 3/38], loss 0.0885, accuracy 0.9727
# epoch [14/30], iter [ 4/38], loss 0.0764, accuracy 0.9844
# epoch [14/30], iter [ 5/38], loss 0.0882, accuracy 0.9766
# epoch [14/30], iter [ 6/38], loss 0.0953, accuracy 0.9688
# epoch [14/30], iter [ 7/38], loss 0.0767, accuracy 0.9766
# epoch [14/30], iter [ 8/38], loss 0.0496, accuracy 0.9883
# epoch [14/30], iter [ 9/38], loss 0.1067, accuracy 0.9648
# epoch [14/30], iter [10/38], loss 0.0900, accuracy 0.9805
# epoch [14/30], iter [11/38], loss 0.0918, accuracy 0.9805
# epoch [14/30], iter [12/38], loss 0.0710, accuracy 0.9805
# epoch [14/30], iter [13/38], loss 0.0662, accuracy 0.9805
# epoch [14/30], iter [14/38], loss 0.0879, accuracy 0.9766
# epoch [14/30], iter [15/38], loss 0.0896, accuracy 0.9766
# epoch [14/30], iter [16/38], loss 0.0711, accuracy 0.9805
# epoch [14/30], iter [17/38], loss 0.0441, accuracy 0.9961
# epoch [14/30], iter [18/38], loss 0.1166, accuracy 0.9648
# epoch [14/30], iter [19/38], loss 0.0746, accuracy 0.9844
# epoch [14/30], iter [20/38], loss 0.0587, accuracy 0.9805
# epoch [14/30], iter [21/38], loss 0.1029, accuracy 0.9648
# epoch [14/30], iter [22/38], loss 0.0875, accuracy 0.9766
# epoch [14/30], iter [23/38], loss 0.0596, accuracy 0.9805
# epoch [14/30], iter [24/38], loss 0.0882, accuracy 0.9727
# epoch [14/30], iter [25/38], loss 0.0814, accuracy 0.9688
# epoch [14/30], iter [26/38], loss 0.0464, accuracy 0.9805
# epoch [14/30], iter [27/38], loss 0.0707, accuracy 0.9805
# epoch [14/30], iter [28/38], loss 0.0765, accuracy 0.9766
# epoch [14/30], iter [29/38], loss 0.0633, accuracy 0.9844
# epoch [14/30], iter [30/38], loss 0.0633, accuracy 0.9805
# epoch [14/30], iter [31/38], loss 0.0565, accuracy 0.9883
# epoch [14/30], iter [32/38], loss 0.0927, accuracy 0.9766
# epoch [14/30], iter [33/38], loss 0.0667, accuracy 0.9844
# epoch [14/30], iter [34/38], loss 0.0834, accuracy 0.9766
# epoch [14/30], iter [35/38], loss 0.0454, accuracy 0.9844
# epoch [14/30], iter [36/38], loss 0.0654, accuracy 0.9805
# epoch [14/30], iter [37/38], loss 0.0712, accuracy 0.9805
# epoch [14/30], iter [38/38], loss 0.0478, accuracy 0.9928
# epoch [14/30], valid acc rate 0.4819
# epoch [14/30] time 89.85579109191895
